# %%
# Out:
# hello world

# %%
print("hello world\ngood boy")
# Out:
# hello world
# good boy

# %%
print("1")
print("22")
print("333")
print("4444")
print("55555")
print("666666")
print("7777777")
# Out:
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777

# %%
print("    1    ")
print("   2 2  ")
print("  3 3 3 ")
print(" 4 4 4 4 ")
# Out:
#     1
#    2 2
#   3 3 3
#  4 4 4 4
